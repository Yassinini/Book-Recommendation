# %% [markdown]
# # FUNCTIONSSSSSSSS

# %% [markdown]
# ## Dataset

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
d = pd.read_csv("clean_books.csv")
d
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 346  Winter of the World: Book Two of the Century T...
# 347  Women Food and God: An Unexpected Path to Almo...
# 348                                             Wonder
# 349       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 350  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year  Genre
# 0                    JJ Smith          4.7    17350      8  2016      1
# 1                Stephen King          4.6     2052     22  2011      0
# 2          Jordan B. Peterson          4.7    18979     15  2018      1
# 3               George Orwell          4.7    21424      6  2017      0
# 4    National Geographic Kids          4.8     7665     12  2019      1
# ..                        ...          ...      ...    ...   ...    ...
# 346               Ken Follett          4.5    10760     15  2012      0
# 347               Geneen Roth          4.2     1302     11  2010      1
# 348             R. J. Palacio          4.8    21625      9  2013      0
# 349               Jeff Kinney          4.9     9413      8  2019      0
# 350               Jen Sincero          4.7    14331      8  2016      1
#
# [351 rows x 7 columns]

# %%
# lay out for v2 idea
# # main -
#       | - option
#          |- option in option

# %% [markdown]
# ## Book by name

# %%
def searchname():
    val = input("Book Name: ")
    typ= "Name"
    out = d[typ].str.contains(val, case=False, na=False) # used AI help for this line
    out = d[out]

    if len(out) ==0 :
        return "Book not found"
    
    elif len(out) ==1 :
        return out
   
    else:
        y = input(f"{out[['Name', 'Author']]} \n please choose a book by index")
        return out.iloc[int(y)]

# %%
searchname()
# Out:
#                  Name               Author  User Rating  Reviews  Price  Year  \
# 252  The Great Gatsby  F. Scott Fitzgerald          4.4    11616      7  2012
#
#      Genre
# 252      0

# %% [markdown]
# ## Book by specifics

# %%
def search(val, typ):
    out = d[typ].str.contains(val, case=False, na=False) # used AI help for this line
    out = d[out]

    if len(out) ==0 :
        return "Book not found"
    
    elif len(out) ==1 :
        return out
   
    else:
        y = input(f"{out[['Name', 'Author']]} \n please choose a book by index")
        return out.iloc[int(y)]

# %%
def specific(d):
    specific = input("Insert number followed by space then the specific available. \n 1. Name \n 2. Author \n 3. User Rating \n 4. Price \n 5. Genre \n ONLY ONE SPECIFIC ")
    
    num, val = specific.split(" ", 1)
    num = int(num)

    match num:
        case 1:
            return search(val, "Name")
        case 2:
            return search(val, "Author")
        case 3:
            return search(val, "User Rating")
        case 4:
            return search(val, "Price")
        case 5:
            return search(val, "Genre")
        case _:
            return "Invalid option"

# %% [markdown]
# ## Book recommend

# %%
def searchtype(typ):
    if typ == 'Price':
        out = d.sort_values(by = typ, ascending=True)
    else:
        out = d.sort_values(by = typ, ascending=False)

    return out

# %%
def recommend():
    r = int(input("Recommend by: \n 1. Rating \n 2. Price \n 3. Reviews \n 4. Year \n 5. Genre"))
    match r:
        case 1:
            return searchtype("User Rating")
        case 2:
            return searchtype("Price")
        case 3:
            return searchtype("Reviews")
        case 4:
            return searchtype("Year")
        case 5:
            return searchtype("Genre")
        case _:
            return "Invalid option"

# %% [markdown]
# # Main

# %%
def main():
    x = int(input("Choose service : \n 1. Book by name \n 2. Book search by specifics \n 3. Book recommendation"))
    match x:
        case 1:
            searchname()
        case 2:
            specific(d)
        case 3:
            recommend()

# %%
main() # get project running
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 main() # get project running
#
# Cell In[22], line 2, in main()
#       1 def main():
# ----> 2     x = int(input("Choose service : \n 1. Book by name \n 2. Book search by specifics \n 3. Book recommendation"))
#       3     match x:
#       4         case 1:
#       5             searchname()
#
# ValueError: invalid literal for int() with base 10: ''
